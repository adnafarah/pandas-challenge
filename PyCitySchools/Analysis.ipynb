# %%
#Import dependencies 
import pandas as pd

# %%
#Specify the paths where the CSV files are stored

path1 = (r'C:\Users\A454\Desktop\clone\UBHM-VIRT-DATA-PT-05-2022-U-LOL\04-Pandas\Home Work\Instructions\PyCitySchools\Resources\schools_complete.csv')
path2 = (r'C:\Users\A454\Desktop\clone\UBHM-VIRT-DATA-PT-05-2022-U-LOL\04-Pandas\Home Work\Instructions\PyCitySchools\Resources\students_complete.csv')

# %%
#Create DataFrames from the above CSV files 
schools_df = pd.read_csv(path1)
students_df = pd.read_csv(path2)

# %%
#view the top 5 rows of the schools DataFrame
schools_df.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
#view the top 5 rows of the students DataFrame
students_df.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
#merge the 2 DataFrames 
complete_df = pd.merge(schools_df, students_df, how="left", on=["school_name", "school_name"])

# %%
#View the top 5 rows of the new DataFrame that has been created
complete_df.head()
# Out:
#    School ID        school_name      type  size   budget  Student ID  \
# 0          0  Huang High School  District  2917  1910635           0
# 1          0  Huang High School  District  2917  1910635           1
# 2          0  Huang High School  District  2917  1910635           2
# 3          0  Huang High School  District  2917  1910635           3
# 4          0  Huang High School  District  2917  1910635           4
#
#         student_name gender grade  reading_score  math_score
# 0       Paul Bradley      M   9th             66          79
# 1       Victor Smith      M  12th             94          61
# 2    Kevin Rodriguez      M  12th             90          60
# 3  Dr. Richard Scott      M  12th             67          58
# 4         Bonnie Ray      F   9th             97          84

# %% [markdown]
# # District Summary

# %%
#Caclulate the total budget by adding up each unique budget
(complete_df["budget"].unique()).sum()
# Out:
# 24649428

# %%
#Calculate the total number of students by adding up the number of unique student IDs
totstudents = len(complete_df["Student ID"].unique())
totstudents
# Out:
# 39170

# %%
#Calculate the total number of schools by adding up the number of unique school names
complete_df["school_name"].nunique()
# Out:
# 15

# %%
#Calculate the average math score
complete_df["math_score"].mean()
# Out:
# 78.98537145774827

# %%
#Calculate the average reading score
complete_df["reading_score"].mean()
# Out:
# 81.87784018381414

# %%
#Calculate the percentage of students with a passing math score (70 or greater)
#filtering by 'math_score' column where the score is 70 or higher 

pass_maths = (complete_df.loc[complete_df["math_score"] >= 70]).count()
#Returns 29370 students, so divide that by total number of students to get the percentage

percent_pass_maths = (29370/39170)*100
percent_pass_maths
# Out:
# 74.9808526933878

# %%
#Calculate the percentage of students with a passing reading score (70 or greater)
#filtering by 'reading_score' column where the score is 70 or higher

pass_reading = (complete_df.loc[complete_df["reading_score"] >= 70]).count()
pass_reading #this returns 33610, so divide that by 39170

(33610/39170)*100
# Out:
# 85.80546336482001

# %%
# Calculate the percentage of students who passed math and reading (% Overall Passing)
#filtering by 'reading_score' and 'math_score' columns where the score for BOTH subjects 70 or higher

overall_pass = (complete_df.loc[(complete_df["math_score"] >= 70) & (
    complete_df["reading_score"] >= 70), :]).count()

overall_pass #returns 25528, so divide that by 39170 to get the percentage
(25528/39170)*100
# Out:
# 65.17232575950983

# %%
#create a DataFrame with the outputs of the previous calculations - creating it by passing a dictionary through the pd.DataFrame

district_summary_df = pd.DataFrame({"Total Schools": [15],
                          "Total Students": [39170],
                          "Total Budget":[24649428],
                          "Average Math Score":[78.98537],
                          "Average Reading Score":[81.877840],
                          "% Passing Math":[74.98085],
                          "% Passing Reading":[85.80546],
                          "% Overall Passing":[65.1723]})
district_summary_df
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428            78.98537
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784        74.98085           85.80546            65.1723

# %% [markdown]
# # School Summary

# %%
complete_df.head()
# Out:
#    School ID        school_name      type  size   budget  Student ID  \
# 0          0  Huang High School  District  2917  1910635           0
# 1          0  Huang High School  District  2917  1910635           1
# 2          0  Huang High School  District  2917  1910635           2
# 3          0  Huang High School  District  2917  1910635           3
# 4          0  Huang High School  District  2917  1910635           4
#
#         student_name gender grade  reading_score  math_score
# 0       Paul Bradley      M   9th             66          79
# 1       Victor Smith      M  12th             94          61
# 2    Kevin Rodriguez      M  12th             90          60
# 3  Dr. Richard Scott      M  12th             67          58
# 4         Bonnie Ray      F   9th             97          84

# %%
grouped = complete_df.groupby(["school_name"])
grouped.head()
# Out:
#        School ID         school_name      type  size   budget  Student ID  \
# 0              0   Huang High School  District  2917  1910635           0
# 1              0   Huang High School  District  2917  1910635           1
# 2              0   Huang High School  District  2917  1910635           2
# 3              0   Huang High School  District  2917  1910635           3
# 4              0   Huang High School  District  2917  1910635           4
# ...          ...                 ...       ...   ...      ...         ...
# 37535         14  Thomas High School   Charter  1635  1043130       37535
# 37536         14  Thomas High School   Charter  1635  1043130       37536
# 37537         14  Thomas High School   Charter  1635  1043130       37537
# 37538         14  Thomas High School   Charter  1635  1043130       37538
# 37539         14  Thomas High School   Charter  1635  1043130       37539
#
#             student_name gender grade  reading_score  math_score
# ...

# %%
# Calculations for Schools Summary

total_students = grouped["Student ID"].count()
total_school_budget = grouped.mean()["budget"] #two rows - total students and total budget per school

per_student_budget =(grouped["budget"].value_counts()) /total_students
average_math = grouped["math_score"].mean()
average_reading = grouped["reading_score"].mean()

pass_maths_per_school = (complete_df["math_score"] >=70).groupby(complete_df.school_name).sum() 
percent_pass_maths_perschool = (pass_maths_per_school /total_students)*100

pass_reading_perschool = (complete_df["reading_score"] >=70).groupby(complete_df.school_name).sum() 
percent_pass_reading_perschool = (pass_reading_perschool / total_students)*100


overall_passed_perschool = (
    (complete_df["math_score"] >= 70) & 
    (complete_df["reading_score"] >= 70)
).groupby(complete_df.school_name).sum()

percent_overall_passed_per = (overall_passed_perschool / total_students)*100

# %%
#create a variable that groups the school types to the school name 

temp = schools_df.set_index(['school_name'])
temp['type']
# Out:
# school_name
# Huang High School        District
# Figueroa High School     District
# Shelton High School       Charter
# Hernandez High School    District
# Griffin High School       Charter
# Wilson High School        Charter
# Cabrera High School       Charter
# Bailey High School       District
# Holden High School        Charter
# Pena High School          Charter
# Wright High School        Charter
# Rodriguez High School    District
# Johnson High School      District
# Ford High School         District
# Thomas High School        Charter
# Name: type, dtype: object

# %%
total_students
# Out:
# school_name
# Bailey High School       4976
# Cabrera High School      1858
# Figueroa High School     2949
# Ford High School         2739
# Griffin High School      1468
# Hernandez High School    4635
# Holden High School        427
# Huang High School        2917
# Johnson High School      4761
# Pena High School          962
# Rodriguez High School    3999
# Shelton High School      1761
# Thomas High School       1635
# Wilson High School       2283
# Wright High School       1800
# Name: Student ID, dtype: int64

# %%
#Building DataFrame summary table for each school

school_summary = pd.DataFrame(total_students)

school_summary["School Type"] = temp['type']
school_summary["Total School Budget"] = grouped.mean()["budget"]
school_summary["Per Student Budget"] = ((grouped["budget"].mean()) /total_students)
school_summary["Average Math Score"]=  grouped["math_score"].mean()
school_summary["Average Reading Score"]= grouped["reading_score"].mean()
school_summary["% Passing Math"] = (pass_maths_per_school /total_students)*100
school_summary["% Passing Reading"] = (pass_reading_perschool / total_students)*100
school_summary["% Overall Passing"] = (overall_passed_perschool / total_students)*100

#view the dataframe
school_summary
# Out:
#                        Student ID School Type  Total School Budget  \
# school_name
# Bailey High School           4976    District            3124928.0
# Cabrera High School          1858     Charter            1081356.0
# Figueroa High School         2949    District            1884411.0
# Ford High School             2739    District            1763916.0
# Griffin High School          1468     Charter             917500.0
# Hernandez High School        4635    District            3022020.0
# Holden High School            427     Charter             248087.0
# Huang High School            2917    District            1910635.0
# Johnson High School          4761    District            3094650.0
# Pena High School              962     Charter             585858.0
# Rodriguez High School        3999    District            2547363.0
# Shelton High School          1761     Charter            1056600.0
# Thomas High School           1635     Charter            1043130.0
# ...

# %%
#'Student ID' column was used to find the number of students as this would be unique to each student, but need to rename this 

school_summary = school_summary.rename(columns={"Student ID": "Total Students"})

school_summary
# Out:
#                        Total Students School Type  Total School Budget  \
# school_name
# Bailey High School               4976    District            3124928.0
# Cabrera High School              1858     Charter            1081356.0
# Figueroa High School             2949    District            1884411.0
# Ford High School                 2739    District            1763916.0
# Griffin High School              1468     Charter             917500.0
# Hernandez High School            4635    District            3022020.0
# Holden High School                427     Charter             248087.0
# Huang High School                2917    District            1910635.0
# Johnson High School              4761    District            3094650.0
# Pena High School                  962     Charter             585858.0
# Rodriguez High School            3999    District            2547363.0
# Shelton High School              1761     Charter            1056600.0
# ...

# %% [markdown]
# # Top Performing Schools (By % Overall Passing)

# %%
school_summary.nlargest(5, "% Overall Passing")
# Out:
#                      Total Students School Type  Total School Budget  \
# school_name
# Cabrera High School            1858     Charter            1081356.0
# Thomas High School             1635     Charter            1043130.0
# Griffin High School            1468     Charter             917500.0
# Wilson High School             2283     Charter            1319574.0
# Pena High School                962     Charter             585858.0
#
#                      Per Student Budget  Average Math Score  \
# school_name
# Cabrera High School               582.0           83.061895
# Thomas High School                638.0           83.418349
# Griffin High School               625.0           83.351499
# Wilson High School                578.0           83.274201
# Pena High School                  609.0           83.839917
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# school_name
# ...

# %% [markdown]
# # Bottom Performing Schools (By % Overall Passing)

# %%
school_summary.nsmallest(5, "% Overall Passing")
# Out:
#                        Total Students School Type  Total School Budget  \
# school_name
# Rodriguez High School            3999    District            2547363.0
# Figueroa High School             2949    District            1884411.0
# Huang High School                2917    District            1910635.0
# Hernandez High School            4635    District            3022020.0
# Johnson High School              4761    District            3094650.0
#
#                        Per Student Budget  Average Math Score  \
# school_name
# Rodriguez High School               637.0           76.842711
# Figueroa High School                639.0           76.711767
# Huang High School                   655.0           76.629414
# Hernandez High School               652.0           77.289752
# Johnson High School                 650.0           77.072464
#
#                        Average Reading Score  % Passing Math  \
# school_name
# ...

# %% [markdown]
# # Reading Scores by Grade

# %%
#Creating a dataframe for each grade (grouped by school), then calculating the mean of each reading score for that grade

#data frame that selects 9th grade, grouped by school
ninth_reading = (
    (complete_df.loc[complete_df["grade"] =="9th"])
                ).groupby(complete_df.school_name)

#calculating average reading score from the above dataframe
ninth_reading_avg = (ninth_reading["reading_score"]).mean()

#repeat above for each grade 

tenth_reading = (
    (complete_df.loc[complete_df["grade"] =="10th"])
                ).groupby(complete_df.school_name)
tenth_read_avg = (tenth_reading["reading_score"]).mean()

eleventh_reading = (
    (complete_df.loc[complete_df["grade"] =="11th"])
                ).groupby(complete_df.school_name)
eleventh_read_avg = (eleventh_reading["reading_score"]).mean()

twelfth_reading = (
    (complete_df.loc[complete_df["grade"] =="12th"])
                ).groupby(complete_df.school_name)
twelfth_read_avg = (twelfth_reading["reading_score"]).mean()

# %%
#Create a dictionary of the above variables calculated 
reading = {"9th": ninth_reading_avg,
            "10th": tenth_read_avg, 
            "11th": eleventh_read_avg,
            "12th": twelfth_read_avg}

#Turn it into a dataframe
reading_df = pd.DataFrame(reading)

#view the top 15 rows of the dataframe (the dataframe is only 15 lines anyway)
reading_df.head(15)
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %% [markdown]
# # Math Scores by Grade

# %%
#Creating a dataframe for each grade (grouped by school), then calculating the mean of each math score for that grade

#data frame that selects 9th grade, grouped by school
ninth_math = (
    (complete_df.loc[complete_df["grade"] =="9th"])
                ).groupby(complete_df.school_name)

#calculating average reading score from the above dataframe
ninth_math_avg = (ninth_math["math_score"]).mean()

#repeat above for each grade 

tenth_math = (
    (complete_df.loc[complete_df["grade"] =="10th"])
                ).groupby(complete_df.school_name)
tenth_math_avg = (tenth_math["math_score"]).mean()

eleventh_math = (
    (complete_df.loc[complete_df["grade"] =="11th"])
                ).groupby(complete_df.school_name)
eleventh_math_avg = (eleventh_math["math_score"]).mean()

twelfth_math = (
    (complete_df.loc[complete_df["grade"] =="12th"])
                ).groupby(complete_df.school_name)
twelfth_math_avg = (twelfth_math["math_score"]).mean()

# %%
#Create a list of the above variables calculated for math
math = {"9th": ninth_math_avg,
            "10th": tenth_math_avg, 
            "11th": eleventh_math_avg,
            "12th": twelfth_math_avg}

#Turn it into a dataframe
math_df = pd.DataFrame(math)

#view the top 15 rows of the dataframe
math_df.head(15)
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %% [markdown]
# # Scores by School Spending

# %%
#make a copy of the school_summary dataframe 

sscopy = school_summary.copy(deep=True)

#reorder the sscopy without mentioning the other columns so they are dropped 
ss2copy = sscopy[["Per Student Budget", "Average Math Score", "Average Reading Score",
                  "% Passing Math", "% Passing Reading", "% Overall Passing"]]

#create the bins
bins = [0, 585, 630, 645, 680]

#create names for the bins
group_names = ["<$585","$585-$630", "$630-$645", "$645-$680"]

#create a new column using pd.cut
ss3["Spending Ranges (Per Student)"] = pd.cut(ss3["Per Student Budget"], bins, labels=group_names, include_lowest=True)

#view what we have so far
ss3.head()
# Out:
#             school_name  Per Student Budget  Average Math Score  \
# 0    Bailey High School               628.0           77.048432
# 1   Cabrera High School               582.0           83.061895
# 2  Figueroa High School               639.0           76.711767
# 3      Ford High School               644.0           77.102592
# 4   Griffin High School               625.0           83.351499
#
#    Average Reading Score  % Passing Math  % Passing Reading  \
# 0              81.033963       66.680064          81.933280
# 1              83.975780       94.133477          97.039828
# 2              81.158020       65.988471          80.739234
# 3              80.746258       68.309602          79.299014
# 4              83.816757       93.392371          97.138965
#
#    % Overall Passing Spending Ranges (Per Student)
# 0          54.642283                     $585-$630
# 1          91.334769                         <$585
# 2          53.204476                     $630-$645
# ...

# %%
#we will need to create a new dataframe, so first we create variables for each column we need

avg_maths = ss3.groupby(["Spending Ranges (Per Student)"]).mean()["Average Math Score"]
avg_read = ss3.groupby(["Spending Ranges (Per Student)"]).mean()["Average Reading Score"]

percent_maths = ss3.groupby(["Spending Ranges (Per Student)"]).mean()["% Passing Math"]
percent_read = ss3.groupby(["Spending Ranges (Per Student)"]).mean()["% Passing Reading"]
overal_passedd = ss3.groupby(["Spending Ranges (Per Student)"]).mean()["% Overall Passing"]

#create dataframe from the above 
school_spending = pd.DataFrame({
    "Average Math Score":avg_maths,
    "Average Reading Score": avg_read,
    "% Passing Math": percent_maths,
    "% Passing Reading": percent_read,
    "% Overall Passing": overal_passedd
})

#view the new dataframe
school_spending
# Out:
#                                Average Math Score  Average Reading Score  \
# Spending Ranges (Per Student)
# <$585                                   83.455399              83.933814
# $585-$630                               81.899826              83.155286
# $630-$645                               78.518855              81.624473
# $645-$680                               76.997210              81.027843
#
#                                % Passing Math  % Passing Reading  \
# Spending Ranges (Per Student)
# <$585                               93.460096          96.610877
# $585-$630                           87.133538          92.718205
# $630-$645                           73.484209          84.391793
# $645-$680                           66.164813          81.133951
#
#                                % Overall Passing
# Spending Ranges (Per Student)
# <$585                                  90.369459
# $585-$630                              81.418596
# ...

# %% [markdown]
# # Scores by School Size

# %%
school_summary
#make another copy of the school_summary dataframe 

sscopy2 = school_summary.copy(deep=True)

#create the bins
bins = [0, 1000, 2000, 5000]

#create names for the bins
group_names = ["Small (<1000)","Medium ((1000-2000))", "Large (2000-5000)"]

#create a new column using pd.cut
sscopy2["School Size"] = pd.cut(another_sscopy["Student ID"], bins, labels=group_names, include_lowest=True)

#view what we have so far
sscopy2.head()
# Out:
#                       Total Students School Type  Total School Budget  \
# school_name
# Bailey High School              4976    District            3124928.0
# Cabrera High School             1858     Charter            1081356.0
# Figueroa High School            2949    District            1884411.0
# Ford High School                2739    District            1763916.0
# Griffin High School             1468     Charter             917500.0
#
#                       Per Student Budget  Average Math Score  \
# school_name
# Bailey High School                 628.0           77.048432
# Cabrera High School                582.0           83.061895
# Figueroa High School               639.0           76.711767
# Ford High School                   644.0           77.102592
# Griffin High School                625.0           83.351499
#
#                       Average Reading Score  % Passing Math  \
# school_name
# Bailey High School                81.033963       66.680064
# ...

# %%
#we will need to create a new dataframe, so first we create variables for each column we need

avg_maths2 = sscopy2.groupby(["School Size"]).mean()["Average Math Score"]
avg_read2 = sscopy2.groupby(["School Size"]).mean()["Average Reading Score"]

percent_maths2 = sscopy2.groupby(["School Size"]).mean()["% Passing Math"]
percent_read2 = sscopy2.groupby(["School Size"]).mean()["% Passing Reading"]
overal_passedd2 = sscopy2.groupby(["School Size"]).mean()["% Overall Passing"]

#create dataframe from the above 
school_size = pd.DataFrame({
    "Average Math Score":avg_maths2,
    "Average Reading Score": avg_read2,
    "% Passing Math": percent_maths2,
    "% Passing Reading": percent_read2,
    "% Overall Passing": overal_passedd2
})

#view the new dataframe
school_size
# Out:
#                       Average Math Score  Average Reading Score  \
# School Size
# Small (<1000)                  83.821598              83.929843
# Medium ((1000-2000))           83.374684              83.864438
# Large (2000-5000)              77.746417              81.344493
#
#                       % Passing Math  % Passing Reading  % Overall Passing
# School Size
# Small (<1000)              93.550225          96.099437          89.883853
# Medium ((1000-2000))       93.599695          96.790680          90.621535
# Large (2000-5000)          69.963361          82.766634          58.286003

# %% [markdown]
# ### Observable trends based on the data

# %% [markdown]
# From the 'Score by School Spending' table, we can see that a higher budget does not result in higher scores for students. Interestingly, the schools with a lowest budget per student had the highest average scores for maths & reading, and the highest pass rates for both subjects. In fact, the school with the highest budget (Johnson High School) was in the bottom 5 schools with the lowest overal pass rate.
#
# The largest schools also had the lowest grades and pass rates overall.
# From the "Math/Reading Scores by Grade" table we can see that the scores don't differ much between the different grades (9th, 10th, 11th, 12th).
